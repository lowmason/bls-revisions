# %%
import polars as pl

# %%
(
    pl
    .read_parquet(
        '/Users/lowell/Projects/bls-revisions/data/vintage_dates.parquet'
    )
    .select('publication', 'revision', 'benchmark_revision')
    .unique()

)
# Out:
# shape: (13, 3)
# ┌─────────────┬──────────┬────────────────────┐
# │ publication ┆ revision ┆ benchmark_revision │
# │ ---         ┆ ---      ┆ ---                │
# │ str         ┆ i32      ┆ i32                │
# ╞═════════════╪══════════╪════════════════════╡
# │ qcew        ┆ 3        ┆ 0                  │
# │ ces         ┆ 0        ┆ 0                  │
# │ qcew        ┆ 1        ┆ 0                  │
# │ sae         ┆ 9        ┆ 2                  │
# │ qcew        ┆ 4        ┆ 0                  │
# │ …           ┆ …        ┆ …                  │
# │ ces         ┆ 9        ┆ 1                  │
# │ sae         ┆ 9        ┆ 1                  │
# │ ces         ┆ 1        ┆ 0                  │
# │ sae         ┆ 1        ┆ 0                  │
# │ qcew        ┆ 2        ┆ 0                  │
# └─────────────┴──────────┴────────────────────┘

# %%
(
    pl
    .read_parquet(
        '/Users/lowell/Projects/bls-revisions/data/ces_revisions.parquet'
    )
)
# Out:
# shape: (22_680, 11)
# ┌────────┬────────────┬────────────┬────────────┬───┬───────────┬──────────┬───────────┬───────────┐
# │ source ┆ seasonally ┆ geographic ┆ geographic ┆ … ┆ vintage_d ┆ revision ┆ benchmark ┆ employmen │
# │ ---    ┆ _adjusted  ┆ _type      ┆ _code      ┆   ┆ ate       ┆ ---      ┆ _revision ┆ t         │
# │ str    ┆ ---        ┆ ---        ┆ ---        ┆   ┆ ---       ┆ i32      ┆ ---       ┆ ---       │
# │        ┆ bool       ┆ str        ┆ str        ┆   ┆ date      ┆          ┆ i32       ┆ f64       │
# ╞════════╪════════════╪════════════╪════════════╪═══╪═══════════╪══════════╪═══════════╪═══════════╡
# │ ces    ┆ false      ┆ national   ┆ 00         ┆ … ┆ 2016-02-0 ┆ 0        ┆ 0         ┆ 141123.0  │
# │        ┆            ┆            ┆            ┆   ┆ 5         ┆          ┆           ┆           │
# │ ces    ┆ false      ┆ national   ┆ 00         ┆ … ┆ 2016-03-0 ┆ 1        ┆ 0         ┆ 141155.0  │
# ...
